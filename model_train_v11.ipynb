# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer, MinMaxScaler
from scipy.sparse import hstack, csr_matrix
from sklearn.neighbors import NearestNeighbors
import joblib

# %%
movies = pd.read_csv("datasets/tmdb_movie_v11.csv")

# %%
movies.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# ...

# %%
movies = movies[movies["original_language"] == "en"]

# %%
movies = movies[movies["spoken_languages"].str.contains("English", na=False, case=False)]

# %%
movies = movies[movies["poster_path"] != ""]

# %%
df = movies.drop(columns=["vote_count", "status", "budget", "homepage", "original_language", "imdb_id", "title", "overview", "backdrop_path", "tagline", "spoken_languages", "production_countries"])

# %%
df.shape[0]
# Out:
# 257095

# %%
df.head()
# Out:
#        id  vote_average release_date     revenue  runtime  adult  \
# 0   27205         8.364   2010-07-15   825532764      148  False
# 1  157336         8.417   2014-11-05   701729206      169  False
# 2     155         8.512   2008-07-16  1004558444      152  False
# 3   19995         7.573   2009-12-15  2923706026      162  False
# 4   24428         7.710   2012-04-25  1518815515      143  False
#
#     original_title  popularity                       poster_path  \
# 0        Inception      83.952  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1     Interstellar     140.241  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2  The Dark Knight     130.643  /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3           Avatar      79.932  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4     The Avengers      98.082   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# ...

# %%
df["genres"] = df["genres"].apply(lambda x: x.split(", ") if isinstance(x, str) else [])
df["keywords"] = df["keywords"].apply(lambda x: x.split(", ") if isinstance(x, str) else [])
df["production_companies"] = df["production_companies"].apply(lambda x: x.split(", ") if isinstance(x, str) else [])

# %%
mlb_genres = MultiLabelBinarizer(sparse_output=True)
genres_binary = csr_matrix(mlb_genres.fit_transform(df["genres"]))

mlb_keywords = MultiLabelBinarizer(sparse_output=True)
keywords_binary = csr_matrix(mlb_keywords.fit_transform(df["keywords"]))

mlb_production = MultiLabelBinarizer(sparse_output=True)
production_companies_binary = csr_matrix(mlb_production.fit_transform(df["production_companies"]))

# %%
scaler = MinMaxScaler()
df["popularity"] = scaler.fit_transform(df[["popularity"]].astype(np.float32)) * 0.2
df["revenue"] = scaler.fit_transform(df[["revenue"]].astype(np.float32)) * 0.15
df["adult"] = df["adult"].astype(np.int8) * 0.4
df["runtime"] = scaler.fit_transform(df[["runtime"]].astype(np.float32).fillna(df["runtime"].median())) * 0.1
df["vote_average"] = scaler.fit_transform(df[["vote_average"]].astype(np.float32)) * 0.25
df["release_date"] = scaler.fit_transform(df[["release_date"]].apply(lambda x: pd.to_datetime(x, errors="coerce").dt.year.fillna(0).astype(np.int16))) * 0.15

# %%
numerical_features = df[["popularity", "revenue", "runtime", "adult", "vote_average", "release_date"]].values
numerical_features_sparse = csr_matrix(numerical_features)

# %%
feature_matrix = hstack([genres_binary, keywords_binary, production_companies_binary, numerical_features_sparse])

# %%
nn_cosine = NearestNeighbors(metric="cosine", n_neighbors=30).fit(feature_matrix)

# %%
joblib.dump((df, feature_matrix, nn_cosine), "models/mrs_model_v11.pkl.gz", compress=("gzip", 3))
# Out:
# ['models/mrs_model_v11.pkl.gz']
